# %%
import pandas as pd

# %%
sales=pd.read_csv('data.csv')

# %%
sales.head()
# Out:
#                                                                                              00 Blue  \
# 2015-09-26 26 September 2015 29 Young Adults (25-34) M France Seine Saint Denis Bikes  Touring Bikes
# 2014-03-02 2  March     2014 29 Young Adults (25-34) M France Seine Saint Denis Bikes  Touring Bikes
# 2016-03-02 2  March     2016 29 Young Adults (25-34) M France Seine Saint Denis Bikes  Touring Bikes
# 2014-01-04 4  January   2014 31 Young Adults (25-34) F France Seine (Paris)     Bikes  Touring Bikes
# 2016-01-04 4  January   2016 31 Young Adults (25-34) F France Seine (Paris)     Bikes  Touring Bikes
#
#                                                                                                          46"  \
# 2015-09-26 26 September 2015 29 Young Adults (25-34) M France Seine Saint Denis Bikes  Touring-2000 Blue, 46
# 2014-03-02 2  March     2014 29 Young Adults (25-34) M France Seine Saint Denis Bikes  Touring-2000 Blue, 46
# ...

# %%
sales.shape
# Out:
# (3301, 9)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 3301 entries, ('2015-09-26', 26, 'September', 2015, 29, 'Young Adults (25-34)', 'M', 'France', 'Seine Saint Denis', 'Bikes') to ('2016-03-04', 4, 'March', 2016, 37, 'Adults (35-64)', 'F', 'France', 'Seine (Paris)', 'Clothing')
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   00 Blue  3301 non-null   object
#  1    46"     3301 non-null   object
#  2   1        3301 non-null   int64
#  3   755      3301 non-null   int64
#  4   1215     3301 non-null   int64
#  5   241      3301 non-null   int64
#  6   755.1    3301 non-null   int64
#  7   996      3301 non-null   int64
#  8   salaire  3 non-null      float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 257.3+ KB

# %%
sales.describe()
# Out:
#                  1          755         1215           241         755.1  \
# count  3301.000000  3301.000000  3301.000000   3301.000000   3301.000000
# mean      5.293850   753.599212  1219.820963    593.186610   1071.846107
# std       7.836762   603.985499   962.640652    552.312267   1336.803861
# min       1.000000    24.000000    64.000000     26.000000     24.000000
# 25%       1.000000    24.000000    64.000000    266.000000    461.000000
# 50%       1.000000   755.000000  1215.000000    473.000000    755.000000
# 75%       5.000000  1482.000000  2384.000000    852.000000   1482.000000
# max      32.000000  1482.000000  2384.000000  15096.000000  42978.000000
#
#                 996  salaire
# count   3301.000000      3.0
# mean    1665.032717     10.0
# std     1845.160881      5.0
# min       50.000000      5.0
# 25%      727.000000      7.5
# 50%     1204.000000     10.0
# 75%     2289.000000     12.5
# max    58074.000000     15.0

# %%
sales['1'].describe()
# Out:
# count    3301.000000
# mean        5.293850
# std         7.836762
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         5.000000
# max        32.000000
# Name: 1, dtype: float64

# %%
sales['salaire'].mean()
# Out:
# 10.0

# %%
sales['salaire'].max()
# Out:
# 15.0

# %%
sales['salaire'].value_counts()
# Out:
# 5.0     1
# 10.0    1
# 15.0    1
# Name: salaire, dtype: int64

# %%
sales['1215'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales['755'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='755'>

# %%
sales['755'].describe()
# Out:
# count    3301.000000
# mean      753.599212
# std       603.985499
# min        24.000000
# 25%        24.000000
# 50%       755.000000
# 75%      1482.000000
# max      1482.000000
# Name: 755, dtype: float64

# %%
sales['755'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sales.corr()
# Out:
# <ipython-input-174-8c6bb5a772fe>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales.corr()
#                 1       755      1215       241     755.1       996  salaire
# 1        1.000000 -0.616586 -0.612838  0.171819 -0.133623 -0.045379      0.0
# 755     -0.616586  1.000000  0.999973  0.353924  0.507119  0.473344      NaN
# 1215    -0.612838  0.999973  1.000000  0.355970  0.507709  0.474384      NaN
# 241      0.171819  0.353924  0.355970  1.000000  0.888843  0.943290      0.0
# 755.1   -0.133623  0.507119  0.507709  0.888843  1.000000  0.990549      0.0
# 996     -0.045379  0.473344  0.474384  0.943290  0.990549  1.000000      0.0
# salaire  0.000000       NaN       NaN  0.000000  0.000000  0.000000      1.0

# %%
sales['241'].plot(kind='hist', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>
